# %%
from __future__ import print_function, division
from builtins import range
import matplotlib.pyplot as plt
import numpy as np

NUM_TRIALS = 10000
EPS = 0.1
BANDIT_PROBABILITES = [0.2, 0.5, 0.75]

# %%
np.zeros(NUM_TRIALS)
np.random.random() 
np.argmax([1,1,1,2,2,2,])
np.ones(NUM_TRIALS)
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
class Bandit:
    def __init__(self, p):
        #p: the win rate
        self.p = p
        self.p_estimate = 0
        self.N = 0
        
    def pull(self):
        
        return np.random.random() < self.p
    
    def update(self, x):
        self.N  += 1.
        self.p_estimate = ((self.N - 1)*self.p_estimate + x) / self.N

# %%
def experiment():
    bandits = [Bandit(p) for p in BANDIT_PROBABILITES]
    
    rewards = np.zeros(NUM_TRIALS)
    num_times_explored = 0
    num_times_exploited = 0
    num_optimal = 0
    

    optimal_j = np.argmax(b.p for n in bandits)
    print("optimal j:", optimal_j )
    
    for i in range(NUM_TRIALS):
        
        # Use epsilon-greedy to select the next bandit
        if np.random.random() < EPS:
            num_times_explored += 1
            j = np.random.randint(len(bandits))
        
        else:
            num_times_exploited += 1
            j = np.argmax([b.p_estimate for b in bandits])
            
        if j == optimal_j:
            num_optimal +=1
            
        x = bandits[j].pull()
        
        rewards[i] = x
        
        bandits[j].update(x)
        
        for b in bandits:
            print("mean estimate:", b.p_estimate)
        
        # print total reward
        print("total reward earned:", rewards.sum())
        print("overall win rate:", rewards.sum() / NUM_TRIALS)
        print("num_times_explored:", num_times_explored)
        print("num_times_exploited:", num_times_exploited)
        print("num times selected optimal bandit:", num_optimal)
        
        cumulative_rewards = np.cumsum(rewards)
        win_rates = cumulative_rewards / (np.arange(NUM_TRIALS) + 1)
        win_rate = cumulative_rewards / (np.arange(NUM_TRIALS) + 1)
        plt.plot(NUM_TRIALS)
        plt.plot(np.ones(NUM_TRIALS)*np.max(BANDIT_PROBABILITES))
        plt.show()
        
if __name__ == "__main__":
    experiment()
# Out:
# optimal j: 0
# mean estimate: 0.0
# mean estimate: 0
# mean estimate: 0
# total reward earned: 0.0
# overall win rate: 0.0
# num_times_explored: 0
# num_times_exploited: 1
# num times selected optimal bandit: 1
# mean estimate: 0.0
# mean estimate: 0
# mean estimate: 0
# total reward earned: 0.0
# overall win rate: 0.0
# num_times_explored: 0
# num_times_exploited: 2
# num times selected optimal bandit: 2
# mean estimate: 0.0
# mean estimate: 0
# mean estimate: 0
# total reward earned: 0.0
# overall win rate: 0.0
# num_times_explored: 0
# num_times_exploited: 3
# num times selected optimal bandit: 3
# mean estimate: 0.0
# mean estimate: 0
# mean estimate: 0
# total reward earned: 0.0
# overall win rate: 0.0
# num_times_explored: 0
# num_times_exploited: 4
# num times selected optimal bandit: 4
# mean estimate: 0.0
# mean estimate: 0
# mean estimate: 0
# total reward earned: 0.0
# overall win rate: 0.0
# num_times_explored: 0
# num_times_exploited: 5
# num times selected optimal bandit: 5
# mean estimate: 0.0
# mean estimate: 0
# mean estimate: 0
# total reward earned: 0.0
# overall win rate: 0.0
# num_times_explored: 1
# num_times_exploited: 5
# num times selected optimal bandit: 6
# mean estimate: 0.14285714285714285
# mean estimate: 0
# mean estimate: 0
# total reward earned: 1.0
# overall win rate: 0.0001
# num_times_explored: 1
# num_times_exploited: 6
# num times selected optimal bandit: 7
# mean estimate: 0.125
# mean estimate: 0
# mean estimate: 0
# total reward earned: 1.0
# overall win rate: 0.0001
# num_times_explored: 1
# num_times_exploited: 7
# num times selected optimal bandit: 8
# mean estimate: 0.1111111111111111
# mean estimate: 0
# mean estimate: 0
# total reward earned: 1.0
# overall win rate: 0.0001
# num_times_explored: 1
# num_times_exploited: 8
# num times selected optimal bandit: 9
# mean estimate: 0.1
# mean estimate: 0
# mean estimate: 0
# total reward earned: 1.0
# overall win rate: 0.0001
# num_times_explored: 1
# num_times_exploited: 9
# num times selected optimal bandit: 10
# mean estimate: 0.1
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 1.0
# overall win rate: 0.0001
# num_times_explored: 2
# num_times_exploited: 9
# num times selected optimal bandit: 10
# mean estimate: 0.09090909090909091
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 1.0
# overall win rate: 0.0001
# num_times_explored: 2
# num_times_exploited: 10
# num times selected optimal bandit: 11
# mean estimate: 0.16666666666666666
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 2
# num_times_exploited: 11
# num times selected optimal bandit: 12
# mean estimate: 0.15384615384615385
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 2
# num_times_exploited: 12
# num times selected optimal bandit: 13
# mean estimate: 0.14285714285714285
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 3
# num_times_exploited: 12
# num times selected optimal bandit: 14
# mean estimate: 0.13333333333333333
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 3
# num_times_exploited: 13
# num times selected optimal bandit: 15
# mean estimate: 0.125
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 4
# num_times_exploited: 13
# num times selected optimal bandit: 16
# mean estimate: 0.11764705882352941
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 4
# num_times_exploited: 14
# num times selected optimal bandit: 17
# mean estimate: 0.1111111111111111
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 4
# num_times_exploited: 15
# num times selected optimal bandit: 18
# mean estimate: 0.10526315789473684
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 4
# num_times_exploited: 16
# num times selected optimal bandit: 19
# mean estimate: 0.1
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 2.0
# overall win rate: 0.0002
# num_times_explored: 4
# num_times_exploited: 17
# num times selected optimal bandit: 20
# mean estimate: 0.14285714285714285
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 3.0
# overall win rate: 0.0003
# num_times_explored: 4
# num_times_exploited: 18
# num times selected optimal bandit: 21
# mean estimate: 0.18181818181818182
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 4.0
# overall win rate: 0.0004
# num_times_explored: 4
# num_times_exploited: 19
# num times selected optimal bandit: 22
# mean estimate: 0.21739130434782608
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 5.0
# overall win rate: 0.0005
# num_times_explored: 5
# num_times_exploited: 19
# num times selected optimal bandit: 23
# mean estimate: 0.20833333333333334
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 5.0
# overall win rate: 0.0005
# num_times_explored: 5
# num_times_exploited: 20
# num times selected optimal bandit: 24
# mean estimate: 0.24
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 6.0
# overall win rate: 0.0006
# num_times_explored: 5
# num_times_exploited: 21
# num times selected optimal bandit: 25
# mean estimate: 0.23076923076923078
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 6.0
# overall win rate: 0.0006
# num_times_explored: 5
# num_times_exploited: 22
# num times selected optimal bandit: 26
# mean estimate: 0.2222222222222222
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 6.0
# overall win rate: 0.0006
# num_times_explored: 5
# num_times_exploited: 23
# num times selected optimal bandit: 27
# mean estimate: 0.25
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 7.0
# overall win rate: 0.0007
# num_times_explored: 5
# num_times_exploited: 24
# num times selected optimal bandit: 28
# mean estimate: 0.2413793103448276
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 7.0
# overall win rate: 0.0007
# num_times_explored: 5
# num_times_exploited: 25
# num times selected optimal bandit: 29
# mean estimate: 0.26666666666666666
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 8.0
# overall win rate: 0.0008
# num_times_explored: 6
# num_times_exploited: 25
# num times selected optimal bandit: 30
# mean estimate: 0.25806451612903225
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 8.0
# overall win rate: 0.0008
# num_times_explored: 6
# num_times_exploited: 26
# num times selected optimal bandit: 31
# mean estimate: 0.25
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 8.0
# overall win rate: 0.0008
# num_times_explored: 7
# num_times_exploited: 26
# num times selected optimal bandit: 32
# mean estimate: 0.2727272727272727
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 27
# num times selected optimal bandit: 33
# mean estimate: 0.2647058823529412
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 28
# num times selected optimal bandit: 34
# mean estimate: 0.2571428571428571
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 29
# num times selected optimal bandit: 35
# mean estimate: 0.25
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 30
# num times selected optimal bandit: 36
# mean estimate: 0.24324324324324326
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 31
# num times selected optimal bandit: 37
# mean estimate: 0.23684210526315788
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 32
# num times selected optimal bandit: 38
# mean estimate: 0.23076923076923078
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 33
# num times selected optimal bandit: 39
# mean estimate: 0.225
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 34
# num times selected optimal bandit: 40
# mean estimate: 0.21951219512195122
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 35
# num times selected optimal bandit: 41
# mean estimate: 0.21428571428571427
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 36
# num times selected optimal bandit: 42
# mean estimate: 0.20930232558139536
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 7
# num_times_exploited: 37
# num times selected optimal bandit: 43
# mean estimate: 0.20930232558139536
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 8
# num_times_exploited: 37
# num times selected optimal bandit: 43
# mean estimate: 0.20454545454545456
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 8
# num_times_exploited: 38
# num times selected optimal bandit: 44
# mean estimate: 0.2
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 8
# num_times_exploited: 39
# num times selected optimal bandit: 45
# mean estimate: 0.1956521739130435
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 8
# num_times_exploited: 40
# num times selected optimal bandit: 46
# mean estimate: 0.19148936170212766
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 8
# num_times_exploited: 41
# num times selected optimal bandit: 47
# mean estimate: 0.1875
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 8
# num_times_exploited: 42
# num times selected optimal bandit: 48
# mean estimate: 0.1836734693877551
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 9.0
# overall win rate: 0.0009
# num_times_explored: 8
# num_times_exploited: 43
# num times selected optimal bandit: 49
# mean estimate: 0.2
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 10.0
# overall win rate: 0.001
# num_times_explored: 8
# num_times_exploited: 44
# num times selected optimal bandit: 50
# mean estimate: 0.19607843137254902
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 10.0
# overall win rate: 0.001
# num_times_explored: 8
# num_times_exploited: 45
# num times selected optimal bandit: 51
# mean estimate: 0.19230769230769232
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 10.0
# overall win rate: 0.001
# num_times_explored: 8
# num_times_exploited: 46
# num times selected optimal bandit: 52
# mean estimate: 0.18867924528301888
# mean estimate: 0.0
# mean estimate: 0
# total reward earned: 10.0
# overall win rate: 0.001
# num_times_explored: 8
# num_times_exploited: 47
# num times selected optimal bandit: 53
# mean estimate: 0.18867924528301888
# mean estimate: 0.3333333333333333
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 9
# num_times_exploited: 47
# num times selected optimal bandit: 53
# mean estimate: 0.18867924528301888
# mean estimate: 0.25
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 9
# num_times_exploited: 48
# num times selected optimal bandit: 53
# mean estimate: 0.18518518518518517
# mean estimate: 0.25
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 10
# num_times_exploited: 48
# num times selected optimal bandit: 54
# mean estimate: 0.18518518518518517
# mean estimate: 0.2
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 10
# num_times_exploited: 49
# num times selected optimal bandit: 54
# mean estimate: 0.18518518518518517
# mean estimate: 0.16666666666666666
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 10
# num_times_exploited: 50
# num times selected optimal bandit: 54
# mean estimate: 0.18181818181818182
# mean estimate: 0.16666666666666666
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 10
# num_times_exploited: 51
# num times selected optimal bandit: 55
# mean estimate: 0.17857142857142858
# mean estimate: 0.16666666666666666
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 10
# num_times_exploited: 52
# num times selected optimal bandit: 56
# mean estimate: 0.17543859649122806
# mean estimate: 0.16666666666666666
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 10
# num_times_exploited: 53
# num times selected optimal bandit: 57
# mean estimate: 0.1724137931034483
# mean estimate: 0.16666666666666666
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 10
# num_times_exploited: 54
# num times selected optimal bandit: 58
# mean estimate: 0.1724137931034483
# mean estimate: 0.14285714285714285
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 11
# num_times_exploited: 54
# num times selected optimal bandit: 58
# mean estimate: 0.1694915254237288
# mean estimate: 0.14285714285714285
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 11
# num_times_exploited: 55
# num times selected optimal bandit: 59
# mean estimate: 0.16666666666666666
# mean estimate: 0.14285714285714285
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 11
# num_times_exploited: 56
# num times selected optimal bandit: 60
# mean estimate: 0.16393442622950818
# mean estimate: 0.14285714285714285
# mean estimate: 0
# total reward earned: 11.0
# overall win rate: 0.0011
# num_times_explored: 11
# num_times_exploited: 57
# num times selected optimal bandit: 61
# mean estimate: 0.1774193548387097
# mean estimate: 0.14285714285714285
# mean estimate: 0
# total reward earned: 12.0
# overall win rate: 0.0012
# num_times_explored: 11
# num_times_exploited: 58
# num times selected optimal bandit: 62
# mean estimate: 0.1746031746031746
# mean estimate: 0.14285714285714285
# mean estimate: 0
# total reward earned: 12.0
# overall win rate: 0.0012
# num_times_explored: 11
# num_times_exploited: 59
# num times selected optimal bandit: 63
# mean estimate: 0.1746031746031746
# mean estimate: 0.125
# mean estimate: 0
# total reward earned: 12.0
# overall win rate: 0.0012
# num_times_explored: 12
# num_times_exploited: 59
# num times selected optimal bandit: 63
# mean estimate: 0.171875
# mean estimate: 0.125
# mean estimate: 0
# total reward earned: 12.0
# overall win rate: 0.0012
# num_times_explored: 12
# num_times_exploited: 60
# num times selected optimal bandit: 64
# mean estimate: 0.18461538461538463
# mean estimate: 0.125
# mean estimate: 0
# total reward earned: 13.0
# overall win rate: 0.0013
# num_times_explored: 12
# num_times_exploited: 61
# num times selected optimal bandit: 65
# mean estimate: 0.18181818181818182
# mean estimate: 0.125
# mean estimate: 0
# total reward earned: 13.0
# overall win rate: 0.0013
# num_times_explored: 12
# num_times_exploited: 62
# num times selected optimal bandit: 66
# mean estimate: 0.1791044776119403
# mean estimate: 0.125
# mean estimate: 0
# total reward earned: 13.0
# overall win rate: 0.0013
# num_times_explored: 12
# num_times_exploited: 63
# num times selected optimal bandit: 67
